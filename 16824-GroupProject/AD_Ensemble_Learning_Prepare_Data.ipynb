# %% [markdown]
# Data from: http://zhao-nas.bio.cmu.edu:5000/fsdownload/aBDx29J7H/Ensemble%20learning%20data_shared

# %%
# import os
# if hasattr(os, 'add_dll_directory'):
#     openslide_dir = r"C:\Users\Windows\Downloads\openslide-win64-20220811\bin"
#     print(f"Adding openslide dir at:{openslide_dir}")
#     with os.add_dll_directory(openslide_dir):
#         import openslide
# else:
#     import openslide
# from tiatoolbox.tools import patchextraction
# from tiatoolbox.utils.misc import imread,  read_locations
# from tiatoolbox.tools import stainnorm
# from tiatoolbox import data
# from tiatoolbox.wsicore.wsireader import WSIReader

# %%
from pathlib import Path
import cv2 , os, numpy as np, torch, pandas as pd, tqdm as tqdm, PIL.Image as Image, time
#from pylab import rcParams
import datetime, copy
# 
from torch import nn, optim
import torch.nn.functional as F
import torchvision.transforms as T
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, Dataset
from torchvision import models
from torchsummary import summary
from pytorch_lightning.loops.fit_loop import FitLoop
from pytorch_lightning.loops.loop import Loop
#
from numpy.lib.function_base import select
from sklearn.preprocessing import LabelBinarizer, OneHotEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
#
#import efficientnet_pytorch
import pytorch_lightning as pl, torchmetrics

# %%
prefix=Path('/mnt/c/Users/Mo/Documents/GitHub/CMU/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/')
cwd = Path(os.getcwd())
class PATH_ARGS:
    proj_path = cwd.absolute()  # [CHANGE THIS for new environment]
    print(f"proj path: {proj_path}")
    model_path = proj_path/'model_chkpts'
    # data path
    #data_path = proj_path/'TestingData'   # Test path
    #data_path = proj_path/"Ensemble_learning data"      # [CONFIRM THIS for new environment]
    data_path = proj_path/'dataset'
    data_name = ['cycleGAN_augmented']
    dataindex_path = data_path/'dataIndex.csv'
    # Select data folders here
    #data_name = ['HE images', 'HIPT_AGH_FluorescentImage_R1']
    # 2 groups to classify
    class_names = ['aug_class_0','aug_class_2']

print(f"data path:{PATH_ARGS.data_path}")
def mkdirifNE(p):
    if not os.path.exists(p): os.mkdir(p)

mkdirifNE(PATH_ARGS.model_path)

def load_img(img_paths: list, is_mask=False):
        """ load array from a list of image paths """
        if is_mask: flag = 0
        else: flag = -1
        return np.concatenate([np.expand_dims(cv2.imread(str(img_fp), flag), axis=0)
                               for img_fp in img_paths.tolist()])
def normalize(ratios):
    """normalize a list of ratios to sum to 1"""
    return [r/sum(ratios) for r in ratios]
print(PATH_ARGS.__dict__)
# Out:
# proj path: /mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject
# data path:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset
# {'__module__': '__main__', 'proj_path': PosixPath('/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject'), 'model_path': PosixPath('/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/model_chkpts'), 'data_path': PosixPath('/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset'), 'data_name': ['cycleGAN_augmented'], 'dataindex_path': PosixPath('/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/dataIndex.csv'), 'class_names': ['aug_class_0', 'aug_class_2'], '__dict__': <attribute '__dict__' of 'PATH_ARGS' objects>, '__weakref__': <attribute '__weakref__' of 'PATH_ARGS' objects>, '__doc__': None}

# %%
class preprocessor:
    """
    Preprocessing for generating tiling images from large FOV
    Generate data indexer table to be passed to dataloader
    """
    def __init__(self, data_path:Path, debug:bool=False):
        """ path to large images containing the class folders of images (non-resp , resp)"""
        self.data_path = data_path
        self.debug = debug
        # define names
        self.x_im_col = 'x_img_path'
        self.y_col = 'label'
        self.index_cols = ['parent_path','type', 'tissue', self.x_im_col]
        # 2 indexers for source/tile imgs
        self.idxer_source = dataIndexer(self.data_path/'dataIndex_source.csv', columns=self.index_cols[:-1]+[self.y_col], index_cols=self.index_cols[:-1])
        self.idxer_tile = dataIndexer(self.data_path/'dataIndex_tile.csv', columns=self.index_cols+[self.y_col], index_cols=self.index_cols)
    
    def main(self, selected_folders:list = None,
             splits={'train':0.7, 'val':0.1, 'test':0.2},
             patch_generator:str="basic",
             patch_dims:tuple=(224,224), 
             normalize_stain:bool=True,
             overwrite:bool=False
             ):
        """
        patch_generator: TIA or basic
        """
        # start indexing
        
        print(f"Folders: {selected_folders}")
        self.overwrite = overwrite
        self.generate_all_tiles_all(self.data_path, 
                                    patch_generator=patch_generator,
                                    selected_folders=selected_folders, 
                                    patch_dims=patch_dims,
                                    normalize_stain=normalize_stain)
        dataindex_source = pd.read_csv(self.idxer_source.fp_csv, index_col=self.idxer_source.index_cols)
        dataindex_tile = pd.read_csv(self.idxer_tile.fp_csv, index_col=self.idxer_tile.index_cols)
        if self.debug: print(f"Indexer shape:{dataindex_tile.shape}\n columns: {dataindex_tile.columns}")
        print(f"Generate stratifieid splits.")
        dataindex_source = self.add_stratify_splits(dataindex_source, splits=splits.copy())
        dataindex_tile = self.add_stratify_splits(dataindex_tile, splits=splits.copy())
        dataindex_source.to_csv(self.idxer_source.fp_csv)
        dataindex_tile.to_csv(self.idxer_tile.fp_csv)
        print(f"[INFO] Copy of dataIndex saved to {self.data_path}")
        return dataindex_source, dataindex_tile
        
    
    def generate_all_tiles_all(self, 
                               path2_input_img_dir:Path,
                               patch_generator="basic", 
                               selected_folders:list=[], 
                               patch_dims:tuple=(224,224), 
                               normalize_stain:bool=True) ->None:
        """ 
        selected folders  list[str] 
            names of folders to be included
        """
        for dirp in path2_input_img_dir.iterdir():  # ['HE', 'HIPT']
            # dirs only + selected folders
            if dirp.is_file() or dirp.name not in selected_folders: 
                continue
            print(f"Generating tiles for data folder:{dirp}")
            #if (selected_folders is None) or (not dirp.name in selected_folders): continue
            mkdirifNE(dirp.parent/(dirp.stem+'_processed'))
            for class_dirp in dirp.iterdir(): # ['Res', 'Non-res']
                # Skip file and not selected
                if class_dirp.is_file(): continue
                # generate tiles
                print(f"[DEBUG] Directories:\nclass dirp{class_dirp}\ndirp:{dirp.parent/(dirp.name+'_processed')/class_dirp.name}")
                self.generate_all_tiles(class_dirp,
                                        save_dir_path=dirp.parent/(dirp.name+'_processed')/class_dirp.name,
                                        patch_generator=patch_generator,
                                        patch_dims=patch_dims,
                                        normalize_stain=normalize_stain)

    def generate_all_tiles(self, input_img_dir:Path, 
                           save_dir_path:Path=None,
                           patch_generator:str="basic",
                           normalize_stain: bool=True,
                           patch_dims:tuple=(224,224),
                           ) -> None:
        if save_dir_path is None:
            save_dir_path = input_img_dir/(input_img_dir.stem+"_processed")
        mkdirifNE(save_dir_path)
        # iterate (tissue) images from input_img_dir
        for N, img_fp in enumerate(input_img_dir.iterdir()):  
            print(f"Folder:{img_fp}")
            # only images files
            if not img_fp.is_file() or (img_fp.suffix!= '.png' and img_fp.suffix!= '.tif'): continue
            if self.debug: print(f"Prepare to generate tiles from {img_fp} to be saved to {save_dir_path}")
            # get tiles (generator)
            ref_img = cv2.imread(str(img_fp))  #.astype('uint8')
            print(f"Input image no.:{N} of size {ref_img.shape}")
                # tile methods
            try:
                if patch_generator=="TIA":
                    img_tiles_gen = self.tile_images_TIA(ref_img, patch_dims=patch_dims)
                else:
                    img_tiles_gen = self.tile_images_basic(ref_img, patch_dims=patch_dims)
            except Exception as e:
                print(f"Error {e} encountered, skipping {img_fp}")
            # normalize
            if normalize_stain: normalizer = self.stain_normalizer(ref_img)
            # idx source img
            self.idxer_source.write(
                        pd.DataFrame(data={
                            'parent_path':[input_img_dir], 'type':[input_img_dir.parent.stem], 
                            'tissue': [img_fp.name], self.y_col:[input_img_dir.stem]}
                        )
            )
            for tile_n, img_tile in enumerate(img_tiles_gen):                
                save_fn = save_dir_path/f"{img_fp.resolve().stem}_t{tile_n}{img_fp.resolve().suffix}"
                if self.debug: print(f"Saving tile {tile_n} to {save_fn}")
                # add to index (relative_path)
                if type(img_tile)==np.ndarray and img_tile.shape==patch_dims+(3,):
                    self.idxer_tile.write(
                        pd.DataFrame(data={
                            'parent_path':[save_fn.parent], 'type':[input_img_dir.parent.stem], 
                            'tissue': [img_fp.name], self.x_im_col:[save_fn.name], self.y_col:[input_img_dir.stem]}
                        )
                    )
                try:
                    if save_fn.is_file() and not self.overwrite:   # Skip exist
                        if self.debug: print(f"\t\tSKipped...exist."); 
                        time.sleep(0.001)
                        continue
                    if normalize_stain: 
                        img_tile = normalizer.transform(img_tile)
                    # write tile
                    im = Image.fromarray(img_tile).save(str(save_fn))
                    time.sleep(0.001)
                except:
                    if self.debug: print(f"Failed for: {save_fn}")


    def tile_images_TIA(self, input_img: np.array, patch_dims=(224,224), stride=None):
        """ Tiling function from TIA 
        return generaor object """
        if not stride: stride = patch_dims
        fixed_patch_extractor = patchextraction.get_patch_extractor(
            input_img=input_img,  # input image path, numpy array, or WSI object
            # locations_list=np.array(centroids_list),
            method_name="slidingwindow",  # also supports "point" and "slidingwindow"
            patch_size=patch_dims,  # size of the patch to extract around the centroids from centroids_list
            stride=stride,  # 250 pixels overlap in both axes
            resolution=0,
            units="level",
        )
        return fixed_patch_extractor
    
    def tile_images_basic(self, im:np.array, patch_dims=(224,224)):
        """ return generator object"""
        M, N = patch_dims
        for y in range(0, im.shape[1]-N, N):
            for x in range(0,im.shape[0]-M, M):
                yield im[x:x+M, y:y+N,:]
    
    def stain_normalizer(self, target_section_image, method_name:str='Reinhard'):
        """ use entire section as input
        target_section_image: np.array
        """
        stain_normalizer = stainnorm.get_normalizer(method_name)
        stain_normalizer.fit(target_section_image)
        return stain_normalizer

    def tissue_segmenter(self, input_img_path:str=None):
        wsi = WSIReader.open(input_img=input_img_path, power=20)
        if self.debug: print(wsi.info.as_dict())
        wsi_thumb = wsi.slide_thumbnail(resolution=1.25, units="power")
        mask = wsi.tissue_mask(resolution=1.25, units="power")
        mask_thumb = mask.slide_thumbnail(
            resolution=1.25, units="power"
        )  # extracting the mask_thumb at the same resolution as wsi_thumb
        if self.debug: print(type(mask_thumb), mask_thumb.dtype, mask_thumb.shape)
        pass

    def add_stratify_splits(self, data_index: pd.DataFrame,
                            splits:dict={'train':0.7, 'val':0.1, 'test':0.2}, stratify:bool= True):
        '''stratify train test split'''
        data_index_split = data_index.copy()
        split_names = list(splits.keys())
        print(data_index_split.shape)
        for sp_name in split_names[:-1]:
            # ttsplit & stratify 
            label_col = data_index_split[self.y_col]
            (_, _, _, _, ind_train, ind_test)  = train_test_split(
                np.arange(len(label_col)), label_col, 
                label_col.index, stratify=label_col if stratify else None, test_size=1-(splits[sp_name]/sum(splits.values()))
            )
            # set defined （'train') set in data_index 
            print(f"Split set:{sp_name}")
            data_index.loc[ind_train, 'set'] = sp_name
            # remove training set
            data_index_split = data_index_split.loc[ind_test]
            splits.pop(sp_name)
        # last type
        data_index.loc[ind_test, 'set'] = split_names[-1]
        # show group stats
        print("Group stats:\n",data_index.groupby('set')['set'].apply(lambda x: len(x)))
        return data_index

class dataIndexer:
    def __init__(self, fp_csv, columns=[], index_cols=[]):
        self.fp_csv = fp_csv
        self.index_cols = index_cols
        data_index = pd.DataFrame(dict.fromkeys(columns), index=[]).set_index(index_cols)  # all are index except y_col
        data_index.to_csv(fp_csv)
        
    def write(self, dataframe_row, on:bool=True):
        dataframe_row.set_index(self.index_cols).to_csv(self.fp_csv, mode='a', header=False)

# %%
# pass data folder 
print(PATH_ARGS.data_path)
prep = preprocessor(PATH_ARGS.data_path, debug=False)
print(prep.index_cols)
# Out:
# /mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset
# ['parent_path', 'type', 'tissue', 'x_img_path']

# %%
tt_splits = {'train':0.7, 'val':0.1, 'test':0.2}
data_index_df = prep.main(
    selected_folders=PATH_ARGS.data_name, splits=tt_splits, 
    patch_generator="basic",
    patch_dims=(224, 224),
    normalize_stain=False,); 
data_index_df[1].head(2)
# Out:
# Folders: ['cycleGAN_augmented']
# Generating tiles for data folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented
# [DEBUG] Directories:
# class dirp/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0
# dirp:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented_processed/aug_class_0
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16274, y=23991, w=3780, h=3638)_t104_fake_B.png
# Input image no.:0 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16274, y=23991, w=3780, h=3638)_t111_fake_B.png
# Input image no.:1 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16274, y=23991, w=3780, h=3638)_t142_fake_B.png
# Input image no.:2 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16274, y=23991, w=3780, h=3638)_t204_fake_B.png
# Input image no.:3 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16274, y=23991, w=3780, h=3638)_t30_fake_B.png
# Input image no.:4 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16274, y=23991, w=3780, h=3638)_t63_fake_B.png
# Input image no.:5 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t109_fake_B.png
# Input image no.:6 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t133_fake_B.png
# Input image no.:7 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t162_fake_B.png
# Input image no.:8 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t200_fake_B.png
# Input image no.:9 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t215_fake_B.png
# Input image no.:10 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t270_fake_B.png
# Input image no.:11 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t271_fake_B.png
# Input image no.:12 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t300_fake_B.png
# Input image no.:13 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t339_fake_B.png
# Input image no.:14 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t371_fake_B.png
# Input image no.:15 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t373_fake_B.png
# Input image no.:16 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=16466, y=14955, w=4701, h=4701)_t49_fake_B.png
# Input image no.:17 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=20125, y=20755, w=4086, h=4063)_t136_fake_B.png
# Input image no.:18 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=20125, y=20755, w=4086, h=4063)_t137_fake_B.png
# Input image no.:19 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=20125, y=20755, w=4086, h=4063)_t170_fake_B.png
# Input image no.:20 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=20125, y=20755, w=4086, h=4063)_t200_fake_B.png
# Input image no.:21 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=20125, y=20755, w=4086, h=4063)_t214_fake_B.png
# Input image no.:22 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=20125, y=20755, w=4086, h=4063)_t296_fake_B.png
# Input image no.:23 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=20125, y=20755, w=4086, h=4063)_t297_fake_B.png
# Input image no.:24 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA-24_0000023786_2021-03-22 09_49_45.scn - Series 1 (1, x=20125, y=20755, w=4086, h=4063)_t2_fake_B.png
# Input image no.:25 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (1)_t154_fake_B.png
# Input image no.:26 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (1)_t38_fake_B.png
# Input image no.:27 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (1)_t59_fake_B.png
# Input image no.:28 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (1)_t71_fake_B.png
# Input image no.:29 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (10)_t112_fake_B.png
# Input image no.:30 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (10)_t140_fake_B.png
# Input image no.:31 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (10)_t200_fake_B.png
# Input image no.:32 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (10)_t221_fake_B.png
# Input image no.:33 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (10)_t228_fake_B.png
# Input image no.:34 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (10)_t233_fake_B.png
# Input image no.:35 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (10)_t86_fake_B.png
# Input image no.:36 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (10)_t88_fake_B.png
# Input image no.:37 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1063_fake_B.png
# Input image no.:38 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1082_fake_B.png
# Input image no.:39 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1085_fake_B.png
# Input image no.:40 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1104_fake_B.png
# Input image no.:41 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1138_fake_B.png
# Input image no.:42 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1175_fake_B.png
# Input image no.:43 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1178_fake_B.png
# Input image no.:44 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1280_fake_B.png
# Input image no.:45 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t134_fake_B.png
# Input image no.:46 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1364_fake_B.png
# Input image no.:47 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1400_fake_B.png
# Input image no.:48 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1408_fake_B.png
# Input image no.:49 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1422_fake_B.png
# Input image no.:50 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1547_fake_B.png
# Input image no.:51 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1561_fake_B.png
# Input image no.:52 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1563_fake_B.png
# Input image no.:53 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1583_fake_B.png
# Input image no.:54 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1608_fake_B.png
# Input image no.:55 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1631_fake_B.png
# Input image no.:56 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t1780_fake_B.png
# Input image no.:57 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t179_fake_B.png
# Input image no.:58 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t231_fake_B.png
# Input image no.:59 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t323_fake_B.png
# Input image no.:60 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t330_fake_B.png
# Input image no.:61 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t332_fake_B.png
# Input image no.:62 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t39_fake_B.png
# Input image no.:63 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t433_fake_B.png
# Input image no.:64 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t471_fake_B.png
# Input image no.:65 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t487_fake_B.png
# Input image no.:66 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t56_fake_B.png
# Input image no.:67 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t572_fake_B.png
# Input image no.:68 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t586_fake_B.png
# Input image no.:69 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t624_fake_B.png
# Input image no.:70 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t659_fake_B.png
# Input image no.:71 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t664_fake_B.png
# Input image no.:72 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t70_fake_B.png
# Input image no.:73 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t737_fake_B.png
# Input image no.:74 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t751_fake_B.png
# Input image no.:75 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t775_fake_B.png
# Input image no.:76 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t832_fake_B.png
# Input image no.:77 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t903_fake_B.png
# Input image no.:78 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t913_fake_B.png
# Input image no.:79 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t970_fake_B.png
# Input image no.:80 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (11)_t975_fake_B.png
# Input image no.:81 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1003_fake_B.png
# Input image no.:82 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1041_fake_B.png
# Input image no.:83 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1045_fake_B.png
# Input image no.:84 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1048_fake_B.png
# Input image no.:85 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1112_fake_B.png
# Input image no.:86 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t113_fake_B.png
# Input image no.:87 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1167_fake_B.png
# Input image no.:88 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t118_fake_B.png
# Input image no.:89 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1198_fake_B.png
# Input image no.:90 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1286_fake_B.png
# Input image no.:91 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1316_fake_B.png
# Input image no.:92 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1327_fake_B.png
# Input image no.:93 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1329_fake_B.png
# Input image no.:94 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t137_fake_B.png
# Input image no.:95 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1410_fake_B.png
# Input image no.:96 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1413_fake_B.png
# Input image no.:97 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1486_fake_B.png
# Input image no.:98 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1490_fake_B.png
# Input image no.:99 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t152_fake_B.png
# Input image no.:100 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1532_fake_B.png
# Input image no.:101 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1537_fake_B.png
# Input image no.:102 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1628_fake_B.png
# Input image no.:103 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1645_fake_B.png
# Input image no.:104 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1676_fake_B.png
# Input image no.:105 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t171_fake_B.png
# Input image no.:106 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1758_fake_B.png
# Input image no.:107 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t1763_fake_B.png
# Input image no.:108 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t272_fake_B.png
# Input image no.:109 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t301_fake_B.png
# Input image no.:110 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t308_fake_B.png
# Input image no.:111 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t426_fake_B.png
# Input image no.:112 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t446_fake_B.png
# Input image no.:113 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t453_fake_B.png
# Input image no.:114 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t530_fake_B.png
# Input image no.:115 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t544_fake_B.png
# Input image no.:116 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t550_fake_B.png
# Input image no.:117 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t552_fake_B.png
# Input image no.:118 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t580_fake_B.png
# Input image no.:119 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t586_fake_B.png
# Input image no.:120 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t670_fake_B.png
# Input image no.:121 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t691_fake_B.png
# Input image no.:122 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t695_fake_B.png
# Input image no.:123 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t724_fake_B.png
# Input image no.:124 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t778_fake_B.png
# Input image no.:125 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t79_fake_B.png
# Input image no.:126 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t833_fake_B.png
# Input image no.:127 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t863_fake_B.png
# Input image no.:128 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t8_fake_B.png
# Input image no.:129 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t927_fake_B.png
# Input image no.:130 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t951_fake_B.png
# Input image no.:131 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (12)_t976_fake_B.png
# Input image no.:132 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (2)_t13_fake_B.png
# Input image no.:133 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (2)_t168_fake_B.png
# Input image no.:134 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (2)_t209_fake_B.png
# Input image no.:135 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (2)_t226_fake_B.png
# Input image no.:136 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (2)_t91_fake_B.png
# Input image no.:137 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (3)_t114_fake_B.png
# Input image no.:138 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (3)_t117_fake_B.png
# Input image no.:139 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (3)_t122_fake_B.png
# Input image no.:140 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (3)_t21_fake_B.png
# Input image no.:141 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (3)_t27_fake_B.png
# Input image no.:142 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t100_fake_B.png
# Input image no.:143 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1054_fake_B.png
# Input image no.:144 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1055_fake_B.png
# Input image no.:145 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1066_fake_B.png
# Input image no.:146 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t107_fake_B.png
# Input image no.:147 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1140_fake_B.png
# Input image no.:148 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1186_fake_B.png
# Input image no.:149 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1281_fake_B.png
# Input image no.:150 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1296_fake_B.png
# Input image no.:151 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t12_fake_B.png
# Input image no.:152 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1307_fake_B.png
# Input image no.:153 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1324_fake_B.png
# Input image no.:154 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t133_fake_B.png
# Input image no.:155 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1421_fake_B.png
# Input image no.:156 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1429_fake_B.png
# Input image no.:157 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1467_fake_B.png
# Input image no.:158 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1493_fake_B.png
# Input image no.:159 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1517_fake_B.png
# Input image no.:160 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1519_fake_B.png
# Input image no.:161 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1521_fake_B.png
# Input image no.:162 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t152_fake_B.png
# Input image no.:163 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1553_fake_B.png
# Input image no.:164 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1580_fake_B.png
# Input image no.:165 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t1662_fake_B.png
# Input image no.:166 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t16_fake_B.png
# Input image no.:167 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t242_fake_B.png
# Input image no.:168 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t435_fake_B.png
# Input image no.:169 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t439_fake_B.png
# Input image no.:170 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t521_fake_B.png
# Input image no.:171 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t650_fake_B.png
# Input image no.:172 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t689_fake_B.png
# Input image no.:173 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t777_fake_B.png
# Input image no.:174 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t814_fake_B.png
# Input image no.:175 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t837_fake_B.png
# Input image no.:176 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t881_fake_B.png
# Input image no.:177 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (4)_t88_fake_B.png
# Input image no.:178 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t102_fake_B.png
# Input image no.:179 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t121_fake_B.png
# Input image no.:180 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t145_fake_B.png
# Input image no.:181 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t159_fake_B.png
# Input image no.:182 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t24_fake_B.png
# Input image no.:183 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t252_fake_B.png
# Input image no.:184 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t288_fake_B.png
# Input image no.:185 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t29_fake_B.png
# Input image no.:186 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t361_fake_B.png
# Input image no.:187 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t386_fake_B.png
# Input image no.:188 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t506_fake_B.png
# Input image no.:189 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t518_fake_B.png
# Input image no.:190 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t576_fake_B.png
# Input image no.:191 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t578_fake_B.png
# Input image no.:192 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t600_fake_B.png
# Input image no.:193 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t616_fake_B.png
# Input image no.:194 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t620_fake_B.png
# Input image no.:195 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t675_fake_B.png
# Input image no.:196 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t677_fake_B.png
# Input image no.:197 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t696_fake_B.png
# Input image no.:198 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t707_fake_B.png
# Input image no.:199 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t741_fake_B.png
# Input image no.:200 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t844_fake_B.png
# Input image no.:201 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (5)_t97_fake_B.png
# Input image no.:202 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (6)_t183_fake_B.png
# Input image no.:203 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (6)_t248_fake_B.png
# Input image no.:204 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_0/NA11_0000020321_2020-10-07 10_47_44 (6)_t285_fake_B.png
# Input image no.:205 of size (256, 256, 3)
# ...
# Input image no.:937 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t322_fake_B.png
# Input image no.:938 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t344_fake_B.png
# Input image no.:939 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t356_fake_B.png
# Input image no.:940 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t367_fake_B.png
# Input image no.:941 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t377_fake_B.png
# Input image no.:942 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t393_fake_B.png
# Input image no.:943 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t3_fake_B.png
# Input image no.:944 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t430_fake_B.png
# Input image no.:945 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t583_fake_B.png
# Input image no.:946 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t643_fake_B.png
# Input image no.:947 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t750_fake_B.png
# Input image no.:948 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t781_fake_B.png
# Input image no.:949 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t797_fake_B.png
# Input image no.:950 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t833_fake_B.png
# Input image no.:951 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t847_fake_B.png
# Input image no.:952 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t899_fake_B.png
# Input image no.:953 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t918_fake_B.png
# Input image no.:954 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t925_fake_B.png
# Input image no.:955 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (8)_t942_fake_B.png
# Input image no.:956 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1019_fake_B.png
# Input image no.:957 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1023_fake_B.png
# Input image no.:958 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1047_fake_B.png
# Input image no.:959 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1053_fake_B.png
# Input image no.:960 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1056_fake_B.png
# Input image no.:961 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1099_fake_B.png
# Input image no.:962 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1109_fake_B.png
# Input image no.:963 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1154_fake_B.png
# Input image no.:964 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1164_fake_B.png
# Input image no.:965 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1171_fake_B.png
# Input image no.:966 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1178_fake_B.png
# Input image no.:967 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1194_fake_B.png
# Input image no.:968 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1215_fake_B.png
# Input image no.:969 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1236_fake_B.png
# Input image no.:970 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1242_fake_B.png
# Input image no.:971 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t127_fake_B.png
# Input image no.:972 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1284_fake_B.png
# Input image no.:973 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1295_fake_B.png
# Input image no.:974 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1350_fake_B.png
# Input image no.:975 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1444_fake_B.png
# Input image no.:976 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1477_fake_B.png
# Input image no.:977 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1493_fake_B.png
# Input image no.:978 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t149_fake_B.png
# Input image no.:979 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t14_fake_B.png
# Input image no.:980 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t150_fake_B.png
# Input image no.:981 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1525_fake_B.png
# Input image no.:982 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1553_fake_B.png
# Input image no.:983 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1580_fake_B.png
# Input image no.:984 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t158_fake_B.png
# Input image no.:985 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1596_fake_B.png
# Input image no.:986 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1606_fake_B.png
# Input image no.:987 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1637_fake_B.png
# Input image no.:988 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1653_fake_B.png
# Input image no.:989 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1688_fake_B.png
# Input image no.:990 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1706_fake_B.png
# Input image no.:991 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1718_fake_B.png
# Input image no.:992 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t1719_fake_B.png
# Input image no.:993 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t201_fake_B.png
# Input image no.:994 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t209_fake_B.png
# Input image no.:995 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t20_fake_B.png
# Input image no.:996 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t286_fake_B.png
# Input image no.:997 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t297_fake_B.png
# Input image no.:998 of size (256, 256, 3)
# Folder:/mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset/cycleGAN_augmented/aug_class_2/NA14PR_0000020323_2020-10-07 10_18_19 (9)_t370_fake_B.png
# Input image no.:999 of size (256, 256, 3)
# Generate stratifieid splits.
# (2000, 1)
# Split set:train
# Split set:val
# Group stats:
#  set
# test      401
# train    1399
# val       200
# Name: set, dtype: int64
# (2000, 1)
# Split set:train
# Split set:val
# Group stats:
#  set
# test      401
# train    1399
# val       200
# Name: set, dtype: int64
# [INFO] Copy of dataIndex saved to /mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Visual Learning/16824-GroupProject/dataset
#                                                                                                                                                                                    label  \
# parent_path                                        type               tissue                                             x_img_path
# /mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Vi... cycleGAN_augmented NA-24_0000023786_2021-03-22 09_49_45.scn - Seri... NA-24_0000023786_2021-03-22 09_49_45.scn - Seri...  aug_class_0
#                                                                       NA-24_0000023786_2021-03-22 09_49_45.scn - Seri... NA-24_0000023786_2021-03-22 09_49_45.scn - Seri...  aug_class_0
#
#                                                                                                                                                                                set
# parent_path                                        type               tissue                                             x_img_path
# /mnt/c/Users/Mo/Documents/GitHub/CMU/16824 - Vi... cycleGAN_augmented NA-24_0000023786_2021-03-22 09_49_45.scn - Seri... NA-24_0000023786_2021-03-22 09_49_45.scn - Seri...  train
#                                                                       NA-24_0000023786_2021-03-22 09_49_45.scn - Seri... NA-24_0000023786_2021-03-22 09_49_45.scn - Seri...    val

# %%
data_index_df = pd.read_csv(PATH_ARGS.data_path/'dataIndex_source.csv')#, index_col=prep.idxer_source.index_cols)
print(data_index_df.columns, data_index_df.shape, prep.idxer_source.index_cols)
data_index_df.head(2)
# Out:
# Index(['parent_path', 'type', 'tissue', 'label', 'set'], dtype='object') (177, 5) ['parent_path', 'type', 'tissue']
#                                    parent_path                type  \
# 0  /mnt/c/data/HE_RBG_Corp_images/NonResponder  HE_RBG_Corp_images
# 1  /mnt/c/data/HE_RBG_Corp_images/NonResponder  HE_RBG_Corp_images
#
#                                               tissue         label    set
# 0  NA-24_0000023786_2021-03-22 09_49_45 - Series ...  NonResponder  train
# 1  NA-24_0000023786_2021-03-22 09_49_45 - Series ...  NonResponder  train

# %%
def check_images(data_index_df,):
    target_shape = (224, 224, 3)
    for img_fp in data_index_df.x_img_path.to_list():
        if np.asarray(Image.open(img_fp)).shape!=target_shape:
            print(f"Incorrect instance at:{img_fp}")
            break
    print("Passed.")
#check_images(data_index_df)
